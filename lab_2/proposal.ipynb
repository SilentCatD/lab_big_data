# %%
# !pip install "gensim==3.8.3"
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: gensim==3.8.3 in /usr/local/lib/python3.9/dist-packages (3.8.3)
# Requirement already satisfied: smart-open>=1.8.1 in /usr/local/lib/python3.9/dist-packages (from gensim==3.8.3) (6.3.0)
# Requirement already satisfied: six>=1.5.0 in /usr/local/lib/python3.9/dist-packages (from gensim==3.8.3) (1.16.0)
# Requirement already satisfied: numpy>=1.11.3 in /usr/local/lib/python3.9/dist-packages (from gensim==3.8.3) (1.22.4)
# Requirement already satisfied: scipy>=0.18.1 in /usr/local/lib/python3.9/dist-packages (from gensim==3.8.3) (1.10.1)

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report, accuracy_score
import pandas as pd
from gensim.test.utils import common_texts
from gensim.sklearn_api import D2VTransformer
# Out:
# [nltk_data] Downloading collection 'popular'
# [nltk_data]    |
# [nltk_data]    | Downloading package cmudict to /root/nltk_data...
# [nltk_data]    |   Package cmudict is already up-to-date!
# [nltk_data]    | Downloading package gazetteers to /root/nltk_data...
# [nltk_data]    |   Package gazetteers is already up-to-date!
# [nltk_data]    | Downloading package genesis to /root/nltk_data...
# [nltk_data]    |   Package genesis is already up-to-date!
# [nltk_data]    | Downloading package gutenberg to /root/nltk_data...
# [nltk_data]    |   Package gutenberg is already up-to-date!
# [nltk_data]    | Downloading package inaugural to /root/nltk_data...
# [nltk_data]    |   Package inaugural is already up-to-date!
# [nltk_data]    | Downloading package movie_reviews to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Package movie_reviews is already up-to-date!
# [nltk_data]    | Downloading package names to /root/nltk_data...
# [nltk_data]    |   Package names is already up-to-date!
# [nltk_data]    | Downloading package shakespeare to /root/nltk_data...
# [nltk_data]    |   Package shakespeare is already up-to-date!
# [nltk_data]    | Downloading package stopwords to /root/nltk_data...
# [nltk_data]    |   Package stopwords is already up-to-date!
# [nltk_data]    | Downloading package treebank to /root/nltk_data...
# [nltk_data]    |   Package treebank is already up-to-date!
# [nltk_data]    | Downloading package twitter_samples to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Package twitter_samples is already up-to-date!
# [nltk_data]    | Downloading package omw to /root/nltk_data...
# [nltk_data]    |   Package omw is already up-to-date!
# [nltk_data]    | Downloading package omw-1.4 to /root/nltk_data...
# [nltk_data]    |   Package omw-1.4 is already up-to-date!
# [nltk_data]    | Downloading package wordnet to /root/nltk_data...
# [nltk_data]    |   Package wordnet is already up-to-date!
# [nltk_data]    | Downloading package wordnet2021 to /root/nltk_data...
# [nltk_data]    |   Package wordnet2021 is already up-to-date!
# [nltk_data]    | Downloading package wordnet31 to /root/nltk_data...
# [nltk_data]    |   Package wordnet31 is already up-to-date!
# [nltk_data]    | Downloading package wordnet_ic to /root/nltk_data...
# [nltk_data]    |   Package wordnet_ic is already up-to-date!
# [nltk_data]    | Downloading package words to /root/nltk_data...
# [nltk_data]    |   Package words is already up-to-date!
# [nltk_data]    | Downloading package maxent_ne_chunker to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Package maxent_ne_chunker is already up-to-date!
# [nltk_data]    | Downloading package punkt to /root/nltk_data...
# [nltk_data]    |   Package punkt is already up-to-date!
# [nltk_data]    | Downloading package snowball_data to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Package snowball_data is already up-to-date!
# [nltk_data]    | Downloading package averaged_perceptron_tagger to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Package averaged_perceptron_tagger is already up-
# [nltk_data]    |       to-date!
# [nltk_data]    |
# [nltk_data]  Done downloading collection popular

# %%
data = pd.read_csv('labeled_data.csv', engine='python')
data.head()
# Out:
#                                               review  \
# 0  It is now past 1 PM and I just finished watchi...
# 1                       I should probably go to bed.
# 2  It's late and tomorrow I have to wake up a bit...
# 3  But not early enough to postpone writing these...
# 4  Now that I have seen it three times, the oppor...
#
#                                       cleaned_review  \
# 0  It is now past PM and I just finished watching...
# 1                       I should probably go to bed
# 2  It s late and tomorrow I have to wake up a bit...
# 3  But not early enough to postpone writing these...
# 4  Now that I have seen it three times the opport...
#
#                                           pos_tagged  \
# 0  [('past', 'a'), ('PM', 'n'), ('finished', 'v')...
# 1     [('probably', 'r'), ('go', 'v'), ('bed', 'v')]
# 2  [('late', 'a'), ('tomorrow', 'n'), ('wake', 'v...
# 3  [('early', 'r'), ('enough', 'r'), ('postpone',...
# 4  [('seen', 'v'), ('three', None), ('times', 'v'...
#
#                                                lemma  \
# 0    past PM finish watch Francis Ford Coppola Go...
# 1                                    probably go bed
# 2                       late tomorrow wake bit early
# 3                   early enough postpone write line
# 4    see three time opportunity share thought ref...
#
#                                          lemma_words  polarity
# 0  ['past', 'PM', 'finish', 'watch', 'Francis', '...  negative
# 1                          ['probably', 'go', 'bed']   neutral
# 2       ['late', 'tomorrow', 'wake', 'bit', 'early']   neutral
# 3   ['early', 'enough', 'postpone', 'write', 'line']  positive
# 4  ['see', 'three', 'time', 'opportunity', 'share...  positive

# %%
data = data[['lemma','lemma_words','polarity']]
data
# Out:
#                                                     lemma  \
# 0         past PM finish watch Francis Ford Coppola Go...
# 1                                         probably go bed
# 2                            late tomorrow wake bit early
# 3                        early enough postpone write line
# 4         see three time opportunity share thought ref...
# ...                                                   ...
# 181911                                                Yes
# 181912                                  best way possible
# 181913                                   Troll II classic
# 181914    Joshua family take trip Nilbog unbeknown kin...
# 181915    mother plain disturb upstart never see perso...
#
#                                               lemma_words  polarity
# 0       ['past', 'PM', 'finish', 'watch', 'Francis', '...  negative
# 1                               ['probably', 'go', 'bed']   neutral
# 2            ['late', 'tomorrow', 'wake', 'bit', 'early']   neutral
# 3        ['early', 'enough', 'postpone', 'write', 'line']  positive
# 4       ['see', 'three', 'time', 'opportunity', 'share...  positive
# ...                                                   ...       ...
# 181911                                            ['Yes']       NaN
# 181912                        ['best', 'way', 'possible']  positive
# 181913                         ['Troll', 'II', 'classic']  positive
# 181914  ['Joshua', 'family', 'take', 'trip', 'Nilbog',...  negative
# 181915  ['mother', 'plain', 'disturb', 'upstart', 'nev...  positive
#
# [181916 rows x 3 columns]

# %%
data_each_polarity = 40000

# %%
pos_data = data.loc[data['polarity'] == 'positive']
pos_data = pos_data.sample(n=data_each_polarity)
pos_data
# Out:
#                                                     lemma  \
# 8124      seem people love movie act talk like movie w...
# 69232     Strong movie definitely first film opinion s...
# 139867              truly script make laugh cry come back
# 71456                                      review helpful
# 45071            side Nebula open Quantum gap thanos army
# ...                                                   ...
# 78215     jarring viewer transport completely differen...
# 144681                                     review helpful
# 107453    Davies Living Daylights play Indiana friend ...
# 49457                                         define real
# 115599    Part one day since bird attack civilization ...
#
#                                               lemma_words  polarity
# 8124    ['seem', 'people', 'love', 'movie', 'act', 'ta...  positive
# 69232   ['Strong', 'movie', 'definitely', 'first', 'fi...  positive
# 139867  ['truly', 'script', 'make', 'laugh', 'cry', 'c...  positive
# 71456                               ['review', 'helpful']  positive
# 45071   ['side', 'Nebula', 'open', 'Quantum', 'gap', '...  positive
# ...                                                   ...       ...
# 78215   ['jarring', 'viewer', 'transport', 'completely...  positive
# 144681                              ['review', 'helpful']  positive
# 107453  ['Davies', 'Living', 'Daylights', 'play', 'Ind...  positive
# 49457                                  ['define', 'real']  positive
# 115599  ['Part', 'one', 'day', 'since', 'bird', 'attac...  positive
#
# [40000 rows x 3 columns]

# %%
neg_data = data.loc[data['polarity'] == 'negative']
neg_data = neg_data.sample(n=data_each_polarity)
neg_data
# Out:
#                                                     lemma  \
# 27424                                       Blowing stuff
# 135055    little know Scientology find picture think s...
# 92729     intense scene movie opinion Jodie Foster sta...
# 13601     Henry become like thug bis life crumbles sur...
# 142864    personal history way hind sight know lot hea...
# ...                                                   ...
# 61833     face Nazi charnel house statement make sink ...
# 20046     Given role narrator mirror cum doppelg nger ...
# 89768               suicide never react appropriate depth
# 138699    sure stop Jonnie embrace within first minute...
# 179015    movie make purely shock value otherwise make...
#
#                                               lemma_words  polarity
# 27424                                ['Blowing', 'stuff']  negative
# 135055  ['little', 'know', 'Scientology', 'find', 'pic...  negative
# 92729   ['intense', 'scene', 'movie', 'opinion', 'Jodi...  negative
# 13601   ['Henry', 'become', 'like', 'thug', 'bis', 'li...  negative
# 142864  ['personal', 'history', 'way', 'hind', 'sight'...  negative
# ...                                                   ...       ...
# 61833   ['face', 'Nazi', 'charnel', 'house', 'statemen...  negative
# 20046   ['Given', 'role', 'narrator', 'mirror', 'cum',...  negative
# 89768   ['suicide', 'never', 'react', 'appropriate', '...  negative
# 138699  ['sure', 'stop', 'Jonnie', 'embrace', 'within'...  negative
# 179015  ['movie', 'make', 'purely', 'shock', 'value', ...  negative
#
# [40000 rows x 3 columns]

# %%
data = pd.concat([pos_data, neg_data], ignore_index=True)
data = data.replace({'polarity': {'negative': 0, 'positive': 1}})
data
# Out:
#                                                    lemma  \
# 0        seem people love movie act talk like movie w...
# 1        Strong movie definitely first film opinion s...
# 2                  truly script make laugh cry come back
# 3                                         review helpful
# 4               side Nebula open Quantum gap thanos army
# ...                                                  ...
# 79995    face Nazi charnel house statement make sink ...
# 79996    Given role narrator mirror cum doppelg nger ...
# 79997              suicide never react appropriate depth
# 79998    sure stop Jonnie embrace within first minute...
# 79999    movie make purely shock value otherwise make...
#
#                                              lemma_words  polarity
# 0      ['seem', 'people', 'love', 'movie', 'act', 'ta...         1
# 1      ['Strong', 'movie', 'definitely', 'first', 'fi...         1
# 2      ['truly', 'script', 'make', 'laugh', 'cry', 'c...         1
# 3                                  ['review', 'helpful']         1
# 4      ['side', 'Nebula', 'open', 'Quantum', 'gap', '...         1
# ...                                                  ...       ...
# 79995  ['face', 'Nazi', 'charnel', 'house', 'statemen...         0
# 79996  ['Given', 'role', 'narrator', 'mirror', 'cum',...         0
# 79997  ['suicide', 'never', 'react', 'appropriate', '...         0
# 79998  ['sure', 'stop', 'Jonnie', 'embrace', 'within'...         0
# 79999  ['movie', 'make', 'purely', 'shock', 'value', ...         0
#
# [80000 rows x 3 columns]

# %%
def transform_and_split(model, data, target):
  X = model.fit_transform(data)
  X_train, X_test, y_train, y_test = train_test_split(
    X, target, test_size=0.2, random_state=42
  )
  return X_train, X_test, y_train, y_test

# %%
def fit_and_benchmark(model, X_train,X_test, y_train, y_test):
  model.fit(X_train, y_train)
  y_pred = model.predict(X_test)
  print(classification_report(y_pred,y_test))
  print("Accuracy:",accuracy_score(y_pred, y_test))

# %%
vectorizer = TfidfVectorizer()
doc2vec = D2VTransformer(min_count=1, size=300)

# %%
rfclf = RandomForestClassifier()
xgb_clf= GradientBoostingClassifier()
lgr = LogisticRegression(max_iter=1000)

# %%
target = data['polarity']
lemma_data = data['lemma']
lemma_words_data = data['lemma_words'].apply(lambda x: x[1:-1].split(','))

# %%
X_train, X_test, y_train, y_test = transform_and_split(vectorizer ,lemma_data, target)

# %%
fit_and_benchmark(rfclf, X_train, X_test, y_train, y_test)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.84      0.85      0.84      7970
#            1       0.85      0.84      0.84      8030
#
#     accuracy                           0.84     16000
#    macro avg       0.84      0.84      0.84     16000
# weighted avg       0.84      0.84      0.84     16000
#
# Accuracy: 0.8433125

# %%
fit_and_benchmark(xgb_clf, X_train, X_test, y_train, y_test)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.90      0.67      0.77     10753
#            1       0.55      0.84      0.67      5247
#
#     accuracy                           0.72     16000
#    macro avg       0.72      0.75      0.72     16000
# weighted avg       0.78      0.72      0.73     16000
#
# Accuracy: 0.72475

# %%
fit_and_benchmark(lgr, X_train, X_test, y_train, y_test)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.90      0.89      0.90      8090
#            1       0.89      0.90      0.89      7910
#
#     accuracy                           0.89     16000
#    macro avg       0.89      0.89      0.89     16000
# weighted avg       0.89      0.89      0.89     16000
#
# Accuracy: 0.8946875

# %%
X_train, X_test, y_train, y_test = transform_and_split(doc2vec ,lemma_words_data, target)

# %%
fit_and_benchmark(rfclf, X_train, X_test, y_train, y_test)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.71      0.61      0.66      9376
#            1       0.54      0.65      0.59      6624
#
#     accuracy                           0.63     16000
#    macro avg       0.63      0.63      0.62     16000
# weighted avg       0.64      0.63      0.63     16000
#
# Accuracy: 0.6265625

# %%
fit_and_benchmark(xgb_clf, X_train, X_test, y_train, y_test)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.73      0.61      0.67      9676
#            1       0.53      0.66      0.59      6324
#
#     accuracy                           0.63     16000
#    macro avg       0.63      0.64      0.63     16000
# weighted avg       0.65      0.63      0.63     16000
#
# Accuracy: 0.6306875

# %%
fit_and_benchmark(lgr, X_train, X_test, y_train, y_test)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.64      0.61      0.63      8437
#            1       0.59      0.62      0.61      7563
#
#     accuracy                           0.62     16000
#    macro avg       0.62      0.62      0.62     16000
# weighted avg       0.62      0.62      0.62     16000
#
# Accuracy: 0.617
